# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "schools_complete.csv"
student_data_to_load = "students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head(10)
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
# 5           5      Bryan Miranda      M   9th  Huang High School
# 6           6      Sheena Carter      F  11th  Huang High School
# 7           7       Nicole Baker      F  12th  Huang High School
# 8           8       Michael Roth      M  10th  Huang High School
# 9           9     Matthew Greene      M  10th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# ...

# %%
#Find number of unique students 

student_name = student_data.loc[:, ["Student ID", "gender", "grade"]]

#Filter out students 

student_name = student_name.drop_duplicates()

#Place unique students in list for later use
    
total_students = student_name.count()[0]

pd.DataFrame({"Total Students": [total_students]})
# Out:
#    Total Students
# 0           39170

# %%
#Find number of schools
school_names = len(school_data_complete["school_name"].unique())

school_names
# Out:
# 15

# %%
#Find total budget for schools

total_budget = school_data["budget"].sum()

total_budget
# Out:
# 24649428

# %%
#Find average of math scores

average_math = school_data_complete["math_score"].mean()

average_math
# Out:
# 78.98537145774827

# %%
#Find aerage reading score

average_reading = school_data_complete["reading_score"].mean()

average_reading
# Out:
# 81.87784018381414

# %%
#Find number of math scores that passed

passing_math = school_data_complete[school_data_complete['math_score'] >= 70]

passing_math
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# ...

# %%
#Find percentage of math scores that passed

percent_math_passed = len(passing_math) / len(school_data_complete) * 100

percent_math_passed
# Out:
# 74.9808526933878

# %%
#Find number of reading scores that passed 

passing_reading = school_data_complete[school_data_complete["reading_score"] >= 70]

passing_reading
# Out:
#        Student ID     student_name gender grade         school_name  \
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 1                 94          61          0  District  2917  1910635
# ...

# %%
#Find percentage of reading scores that passed

percent_reading_passed = len(passing_reading) / len(school_data_complete) * 100

percent_reading_passed
# Out:
# 85.80546336482001

# %%
#Find overall passing score for reading and math
overall_passing_score = percent_reading_passed and percent_math_passed

overall_passing_score
# Out:
# 74.9808526933878

# %%
#Create a Data Frame of the Direct Summary of all the values

district_summary_df = pd.DataFrame({"Number of Unique Schools": school_names, "Total Students": total_students, "Average Math Score": [average_math],
                           "Average Reading Score": [average_reading], "Total Budget": [total_budget], "Students Who Passed Math": percent_math_passed, "Students Who Passed Reading": percent_reading_passed, "Overall Students Who Passed": overall_passing_score})


district_summary_df
# Out:
#    Number of Unique Schools  Total Students  Average Math Score  \
# 0                        15           39170           78.985371
#
#    Average Reading Score  Total Budget  Students Who Passed Math  \
# 0               81.87784      24649428                 74.980853
#
#    Students Who Passed Reading  Overall Students Who Passed
# 0                    85.805463                    74.980853

# %%
#School Summary

# %%
# Find the school type
school_types = school_data.set_index(["school_name"])["type"]
school_types
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
# Calculate the total number of students per school
per_school_counts = school_data_complete.groupby(["school_name"]).count()["student_name"].rename("School Count")
per_school_counts
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: School Count, dtype: int64

# %%
# Calculate the total school budget and per capita spending
per_school_budget = school_data_complete.groupby(["school_name"]).mean()["budget"]
per_school_capita = per_school_budget / per_school_counts
per_school_capita
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
# Count the math score per school
per_school_math = school_data_complete.groupby(["school_name"]).count()["math_score"]

per_school_math
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: math_score, dtype: int64

# %%
#Count the reading scores per schools
per_school_reading = school_data_complete.groupby(["school_name"]).count()["reading_score"]

per_school_reading
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: reading_score, dtype: int64

# %%
# Calculate the number of schools with math scores of 70 or higher
school_passing_math = school_data_complete[(school_data_complete["math_score"] >= 70)]

school_passing_math
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# ...

# %%
#Calculate the number of schools with a reading score of >70 or higher
school_passing_reading = school_data_complete[(school_data_complete["reading_score"] >= 70)]

school_passing_reading
# Out:
#        Student ID     student_name gender grade         school_name  \
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 1                 94          61          0  District  2917  1910635
# ...

# %%
# Use the provided code to calculate the schools that passed both math and reading with scores of 70 or higher
passing_math_and_reading = school_data_complete[(school_data_complete["reading_score"] >= 70) & (school_data_complete["math_score"] >= 70)]

# %%
# Use the provided code to calculate the passing rates
per_school_passing_math = school_passing_math.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100
per_school_passing_reading = school_passing_reading.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100
overall_passing_rate = passing_math_and_reading.groupby(["school_name"]).count()["student_name"] / per_school_counts * 100

# Calculate budget per student per school
per_student_budget = total_students / per_school_capita 
per_student_budget
# Out:
# school_name
# Bailey High School       62.372611
# Cabrera High School      67.302405
# Figueroa High School     61.298905
# Ford High School         60.822981
# Griffin High School      62.672000
# Hernandez High School    60.076687
# Holden High School       67.418244
# Huang High School        59.801527
# Johnson High School      60.261538
# Pena High School         64.318555
# Rodriguez High School    61.491366
# Shelton High School      65.283333
# Thomas High School       61.394984
# Wilson High School       67.768166
# Wright High School       67.186964
# dtype: float64

# %%
# Create a DataFrame called `per_school_summary` with columns for the calculations above.
    #Putting Values into Data Frame
per_school_summary_df = pd.DataFrame({"School Types": school_types, 
                                      "Total Students": per_school_counts,
                                       "Total School Budget": per_school_capita,
                                      "Per Student Budget": per_student_budget,
                                      "Average Math Score":average_math,
                                      "Average Reading Score":average_reading,
                                      "School Passing Math": per_school_passing_math, 
                                       "School Passing Reading": per_school_passing_reading,
                                       "Overall Schools Passing Math & Reading": overall_passing_rate})

# Formatting
per_school_summary_df["Total School Budget"] = per_school_summary_df["Total School Budget"].map("${:,.2f}".format)
per_school_summary_df["Per Student Budget"] = per_school_summary_df["Per Student Budget"].map("${:,.2f}".format)


# Display the DataFrame
per_school_summary_df
# Out:
#                       School Types  Total Students Total School Budget  \
# Bailey High School        District            4976             $628.00
# Cabrera High School        Charter            1858             $582.00
# Figueroa High School      District            2949             $639.00
# Ford High School          District            2739             $644.00
# Griffin High School        Charter            1468             $625.00
# Hernandez High School     District            4635             $652.00
# Holden High School         Charter             427             $581.00
# Huang High School         District            2917             $655.00
# Johnson High School       District            4761             $650.00
# Pena High School           Charter             962             $609.00
# Rodriguez High School     District            3999             $637.00
# Shelton High School        Charter            1761             $600.00
# ...

# %%
# Highest-Performing Schools (By % Overall Passing)

# %%
    #Most Popular Items
    
per_school_summary_df = per_school_summary_df.sort_values(["Overall Schools Passing Math & Reading"], ascending=False)

per_school_summary_df
# Out:
#                       School Types  Total Students Total School Budget  \
# Cabrera High School        Charter            1858             $582.00
# Thomas High School         Charter            1635             $638.00
# Griffin High School        Charter            1468             $625.00
# Wilson High School         Charter            2283             $578.00
# Pena High School           Charter             962             $609.00
# Wright High School         Charter            1800             $583.00
# Shelton High School        Charter            1761             $600.00
# Holden High School         Charter             427             $581.00
# Bailey High School        District            4976             $628.00
# Ford High School          District            2739             $644.00
# Johnson High School       District            4761             $650.00
# Hernandez High School     District            4635             $652.00
# ...

# %%
# Bottom-Performing Schools (By % Overall Passing)

# %%
per_school_summary_df = per_school_summary_df.sort_values(["Overall Schools Passing Math & Reading"], ascending=True)

per_school_summary_df
# Out:
#                       School Types  Total Students Total School Budget  \
# Rodriguez High School     District            3999             $637.00
# Figueroa High School      District            2949             $639.00
# Huang High School         District            2917             $655.00
# Hernandez High School     District            4635             $652.00
# Johnson High School       District            4761             $650.00
# Ford High School          District            2739             $644.00
# Bailey High School        District            4976             $628.00
# Holden High School         Charter             427             $581.00
# Shelton High School        Charter            1761             $600.00
# Wright High School         Charter            1800             $583.00
# Pena High School           Charter             962             $609.00
# Wilson High School         Charter            2283             $578.00
# ...

# %%
# Math Scores by Grades

# %%
# Use the code provided to separate the data by grade
ninth_graders = school_data_complete[(school_data_complete["grade"] == "9th")]
tenth_graders = school_data_complete[(school_data_complete["grade"] == "10th")]
eleventh_graders = school_data_complete[(school_data_complete["grade"] == "11th")]
twelfth_graders = school_data_complete[(school_data_complete["grade"] == "12th")]


# Group by "school_name" and take the mean of each.
ninth_graders_scores = ninth_graders.groupby(["school_name"]).mean()
tenth_graders_scores = tenth_graders.groupby(["school_name"]).mean()
eleventh_graders_scores = eleventh_graders.groupby(["school_name"]).mean()
twelfth_graders_scores = twelfth_graders.groupby(["school_name"]).mean()

# Use the code to select only the `math_score`.
ninth_grade_math_scores = ninth_graders_scores["math_score"]
tenth_grader_math_scores = tenth_graders_scores["math_score"]
eleventh_grader_math_scores = eleventh_graders_scores.mean()["math_score"]
twelfth_grader_math_scores = twelfth_graders_scores["math_score"]

# Combine each of the scores above into single DataFrame called `math_scores_by_grade`

math_scores_by_grade = pd.DataFrame({
        "9th": ninth_grade_math_scores, 
        "10th": tenth_grader_math_scores,
        "11th": eleventh_grader_math_scores, 
        "12th": twelfth_grader_math_scores})


# Minor data wrangling
math_scores_by_grade.index.name = None

# Display the DataFrame
math_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  80.575873  76.492218
# Cabrera High School    83.094697  83.154506  80.575873  83.277487
# Figueroa High School   76.403037  76.539974  80.575873  77.151369
# Ford High School       77.361345  77.672316  80.575873  76.179963
# Griffin High School    82.044010  84.229064  80.575873  83.356164
# Hernandez High School  77.438495  77.337408  80.575873  77.186567
# Holden High School     83.787402  83.429825  80.575873  82.855422
# Huang High School      77.027251  75.908735  80.575873  77.225641
# Johnson High School    77.187857  76.691117  80.575873  76.863248
# Pena High School       83.625455  83.372000  80.575873  84.121547
# Rodriguez High School  76.859966  76.612500  80.575873  77.690748
# Shelton High School    83.420755  82.917411  80.575873  83.778976
# Thomas High School     83.590022  83.087886  80.575873  83.497041
# ...

# %%
# Reading Score by Grade

# %%
# Use the code provided to separate the data by grade
ninth_graders = school_data_complete[(school_data_complete["grade"] == "9th")]
tenth_graders = school_data_complete[(school_data_complete["grade"] == "10th")]
eleventh_graders = school_data_complete[(school_data_complete["grade"] == "11th")]
twelfth_graders = school_data_complete[(school_data_complete["grade"] == "12th")]

# Group by "school_name" and take the mean of each.
ninth_graders_scores = ninth_graders.groupby(["school_name"]).mean()
tenth_graders_scores = tenth_graders.groupby(["school_name"]).mean()
eleventh_graders_scores = eleventh_graders.groupby(["school_name"]).mean()
twelfth_graders_scores = twelfth_graders.groupby(["school_name"]).mean()


# Use the code to select only the `reading_score`.
ninth_grade_reading_scores = ninth_graders_scores["reading_score"]
tenth_grader_reading_scores = tenth_graders_scores["reading_score"]
eleventh_grader_reading_scores = eleventh_graders_scores.mean()["reading_score"]
twelfth_grader_reading_scores = twelfth_graders_scores["reading_score"]

# Combine each of the scores above into single DataFrame called `reading_scores_by_grade`
reading_scores_by_grade = pd.DataFrame({
        "9th": ninth_grade_reading_scores, 
        "10th": tenth_grader_reading_scores,
        "11th": eleventh_grader_reading_scores, 
        "12th": twelfth_grader_reading_scores})


# Minor data wrangling
reading_scores_by_grade = reading_scores_by_grade[["9th", "10th", "11th", "12th"]]
reading_scores_by_grade.index.name = None

# Display the DataFrame
reading_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  82.559485  80.912451
# Cabrera High School    83.676136  84.253219  82.559485  84.287958
# Figueroa High School   81.198598  81.408912  82.559485  81.384863
# Ford High School       80.632653  81.262712  82.559485  80.662338
# Griffin High School    83.369193  83.706897  82.559485  84.013699
# Hernandez High School  80.866860  80.660147  82.559485  80.857143
# Holden High School     83.677165  83.324561  82.559485  84.698795
# Huang High School      81.290284  81.512386  82.559485  80.305983
# Johnson High School    81.260714  80.773431  82.559485  81.227564
# Pena High School       83.807273  83.612000  82.559485  84.591160
# Rodriguez High School  80.993127  80.629808  82.559485  80.376426
# Shelton High School    84.122642  83.441964  82.559485  82.781671
# Thomas High School     83.728850  84.254157  82.559485  83.831361
# ...

# %%
# Scores by School Spending

# %%
# Create a copy of the school summary since it has the "Per Student Budget" 
school_spending_df = per_school_summary_df.copy()

# %%
# Establish the bins 
spending_bins = [0, 585, 630, 645, 680]
labels = ["<$585", "$585-630", "$630-645", "$645-680"]

# %%
# Use `pd.cut` to categorize spending based on the bins.
school_spending_df["Spending Ranges (Per Student)"] = pd.cut(per_school_capita, spending_bins, labels=labels, right=False)

school_spending_df
# Out:
#                       School Types  Total Students Total School Budget  \
# Rodriguez High School     District            3999             $637.00
# Figueroa High School      District            2949             $639.00
# Huang High School         District            2917             $655.00
# Hernandez High School     District            4635             $652.00
# Johnson High School       District            4761             $650.00
# Ford High School          District            2739             $644.00
# Bailey High School        District            4976             $628.00
# Holden High School         Charter             427             $581.00
# Shelton High School        Charter            1761             $600.00
# Wright High School         Charter            1800             $583.00
# Pena High School           Charter             962             $609.00
# Wilson High School         Charter            2283             $578.00
# ...

# %%
#  Calculate averages for the desired columns. 
spending_math_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"]).mean()["Average Math Score"]
spending_reading_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"]).mean()["Average Reading Score"]
spending_passing_math = school_spending_df.groupby(["Spending Ranges (Per Student)"]).mean()["School Passing Math"]
spending_passing_reading = school_spending_df.groupby(["Spending Ranges (Per Student)"]).mean()["School Passing Reading"]
spending_overall_passing = school_spending_df.groupby(["Spending Ranges (Per Student)"]).mean()["Overall Schools Passing Math & Reading"]

# %%
# Assemble into DataFrame
spending_summary_df = pd.DataFrame({
        "School Passing Math": spending_passing_math, 
        "School Passing Reading": spending_passing_reading, "Overall Schools Passing Math & Reading": spending_overall_passing})
# Display results
spending_summary_df
# Out:
#                                School Passing Math  School Passing Reading  \
# Spending Ranges (Per Student)
# <$585                                    93.460096               96.610877
# $585-630                                 87.133538               92.718205
# $630-645                                 73.484209               84.391793
# $645-680                                 66.164813               81.133951
#
#                                Overall Schools Passing Math & Reading
# Spending Ranges (Per Student)
# <$585                                                       90.369459
# $585-630                                                    81.418596
# $630-645                                                    62.857656
# $645-680                                                    53.526855

# %%
# Scores by Schools Size

spending_math_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"]).mean()["School Passing Math"]
spending_reading_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"]).mean()["School Passing Reading"]

# %%
# Establish the bins.
size_bins = [0, 1000, 2000, 5000]
labels = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
# Categorize the spending based on the bins
# Use `pd.cut` on the "Total Students" column of the `per_school_summary` DataFrame.

per_school_summary_df["School Size"] = pd.cut(per_school_summary_df["Total Students"], size_bins, labels=labels, right=False)

per_school_summary_df
# Out:
#                       School Types  Total Students Total School Budget  \
# Rodriguez High School     District            3999             $637.00
# Figueroa High School      District            2949             $639.00
# Huang High School         District            2917             $655.00
# Hernandez High School     District            4635             $652.00
# Johnson High School       District            4761             $650.00
# Ford High School          District            2739             $644.00
# Bailey High School        District            4976             $628.00
# Holden High School         Charter             427             $581.00
# Shelton High School        Charter            1761             $600.00
# Wright High School         Charter            1800             $583.00
# Pena High School           Charter             962             $609.00
# Wilson High School         Charter            2283             $578.00
# ...

# %%
# Calculate averages for the desired columns. 
size_math_scores = per_school_summary_df.groupby(["School Size"]).mean()["Average Math Score"]
size_reading_scores = per_school_summary_df.groupby(["School Size"]).mean()["Average Reading Score"]
size_passing_math = per_school_summary_df.groupby(["School Size"]).mean()["School Passing Math"]
size_passing_reading = per_school_summary_df.groupby(["School Size"]).mean()["School Passing Reading"]
size_overall_passing = per_school_summary_df.groupby(["School Size"]).mean()["Overall Schools Passing Math & Reading"]

# %%
# Create a DataFrame called `size_summary` that breaks down school performance based on school size (small, medium, or large).

# Use the scores above to create a new DataFrame called `size_summary`
size_summary_df = pd.DataFrame({
        "Averge Math Score": size_math_scores, 
        "Average Reading Score": size_reading_scores,
        "School Passing Math": size_passing_math, 
        "School Passing Reading": size_passing_reading,
    "Overall Schools Passing Math & Reading": size_overall_passing})


# Display results
size_summary_df
# Out:
#                     Averge Math Score  Average Reading Score  \
# School Size
# Small (<1000)               78.985371               81.87784
# Medium (1000-2000)          78.985371               81.87784
# Large (2000-5000)           78.985371               81.87784
#
#                     School Passing Math  School Passing Reading  \
# School Size
# Small (<1000)                 93.550225               96.099437
# Medium (1000-2000)            93.599695               96.790680
# Large (2000-5000)             69.963361               82.766634
#
#                     Overall Schools Passing Math & Reading
# School Size
# Small (<1000)                                    89.883853
# Medium (1000-2000)                               90.621535
# Large (2000-5000)                                58.286003

# %%
# Group the per_school_summary DataFrame by "School Type" and average the results.
type_math_scores = per_school_summary_df.groupby("School Types").mean()["Average Math Score"]
type_reading_scores = per_school_summary_df.groupby("School Types").mean()["Average Reading Score"]
type_passing_math = per_school_summary_df.groupby("School Types").mean()["School Passing Math"]
type_passing_reading = per_school_summary_df.groupby("School Types").mean()["School Passing Reading"]
type_overall_passing = per_school_summary_df.groupby("School Types").mean()["Overall Schools Passing Math & Reading"]

# %%
# Assemble the new data by type into a DataFrame called `type_summary`
type_summary_df = pd.DataFrame({
        "Average Math Score": type_math_scores, 
        "Average Reading Score": type_reading_scores,
        "School Passing Math": type_passing_math, 
        "School Passing Reading": type_passing_reading,
    "Overall Schools Passing Math & Reading": type_overall_passing})

# Display results
type_summary_df
# Out:
#               Average Math Score  Average Reading Score  School Passing Math  \
# School Types
# Charter                78.985371               81.87784            93.620830
# District               78.985371               81.87784            66.548453
#
#               School Passing Reading  Overall Schools Passing Math & Reading
# School Types
# Charter                    96.586489                               90.432244
# District                   80.799062                               53.672208

# %%
# Fin
